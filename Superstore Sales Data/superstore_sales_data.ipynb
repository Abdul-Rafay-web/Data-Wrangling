# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ...existing code...
try:
    df = pd.read_csv(r'c:\Users\CSC\Desktop\Rafay\Languages\Python\Data Wrangling\Superstore Sales Data\Superstore.csv', encoding='utf-8')
except UnicodeDecodeError:
    df = pd.read_csv(r'c:\Users\CSC\Desktop\Rafay\Languages\Python\Data Wrangling\Superstore Sales Data\Superstore.csv', encoding='latin-1')
# ...existing code...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])

# %%
df['Shipping Days']=(df['Ship Date']-df['Order Date']).dt.days

# %%
df['Order Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Ship Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156 2013-09-11 2013-11-12    Second Class    CG-12520
# 1       2  CA-2013-152156 2013-09-11 2013-11-12    Second Class    CG-12520
# 2       3  CA-2013-138688        NaT 2013-06-17    Second Class    DV-13045
# 3       4  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
# 4       5  US-2012-108966 2012-11-10 2012-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Shipping Days'].describe()
# Out:
# count    3974.000000
# mean       47.286613
# std       137.652168
# min      -320.000000
# 25%       -54.000000
# 50%        36.000000
# 75%       152.000000
# max       331.000000
# Name: Shipping Days, dtype: float64

# %%
negative_shipments=df[df['Shipping Days']<0]

# %%
negative_shipments[['Order Date','Ship Date','Shipping Days']].value_counts()
# Out:
# Order Date  Ship Date   Shipping Days
# 2013-12-11  2013-11-17  -24.0            13
# 2014-09-07  2014-07-13  -56.0            13
# 2014-10-09  2014-09-14  -25.0            11
# 2012-09-07  2012-07-14  -55.0            11
# 2013-05-02  2013-02-05  -86.0            11
#                                          ..
# 2014-12-11  2014-11-16  -25.0             1
# 2014-12-08  2014-08-17  -113.0            1
# 2011-06-01  2011-01-13  -139.0            1
# 2011-04-01  2011-01-08  -83.0             1
# 2011-03-02  2011-02-07  -23.0             1
# Name: count, Length: 505, dtype: int64

# %% [markdown]
# The number of error dates are 505

# %%
df.isna().sum()
# Out:
# Row ID              0
# Order ID            0
# Order Date       6020
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Days    6020
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Order Date'].fillna('Unknown')
# Out:
# 0       2013-09-11 00:00:00
# 1       2013-09-11 00:00:00
# 2                   Unknown
# 3       2012-11-10 00:00:00
# 4       2012-11-10 00:00:00
#                ...
# 9989                Unknown
# 9990                Unknown
# 9991                Unknown
# 9992                Unknown
# 9993    2014-05-05 00:00:00
# Name: Order Date, Length: 9994, dtype: object

# %%
df.isna().sum()
# Out:
# Row ID              0
# Order ID            0
# Order Date       6020
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Days    6020
# dtype: int64
